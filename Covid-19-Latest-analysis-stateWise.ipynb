# %%
import pandas as pd

# %%
covid = pd.read_csv("Latest Covid-19 India Status.csv")

# %%
covid.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7549       1        7419     129
# 1       Andhra Pradesh      1995669   16341     1965657   13671
# 2    Arunachal Pradesh        51655    1763       49640     252
# 3                Assam       581398    8772      567113    5513
# 4                Bihar       725518     204      715665    9649
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.01                98.28             1.71
# 1              0.82                98.50             0.69
# 2              3.41                96.10             0.49
# 3              1.51                97.54             0.95
# 4              0.03                98.64             1.33

# %%
covid.shape
# Out:
# (36, 8)

# %% [markdown]
# # Important insights

# %% [markdown]
# # 1. Highest Recovery

# %%
recovery = covid.sort_values('Discharge Ratio (%)', ascending = False)
recovery
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        10657       4       10649
# 18                               Lakshadweep        10295      34       10210
# 28                                 Rajasthan       953960     163      944843
# 10                                   Gujarat       825213     179      814956
# 11                                   Haryana       770245     660      759924
# 19                            Madhya Pradesh       792054      95      781444
# 33                             Uttar Pradesh      1708991     420     1685785
# 4                                      Bihar       725518     204      715665
# 5                                 Chandigarh        62035      42       61182
# 17                                    Ladakh        20466      81       20178
# 6                               Chhattisgarh      1003870    1037      989284
# ...

# %% [markdown]
# # 2. Most Active Case

# %%
active = covid.sort_values("Active", ascending = False)

# %%
active
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 16                                    Kerala      3724030  175695     3529465
# 20                               Maharashtra      6401213   64790     6201168
# 15                                 Karnataka      2931827   21507     2873281
# 30                                Tamil Nadu      2592436   20225     2537632
# 1                             Andhra Pradesh      1995669   16341     1965657
# 35                               West Bengal      1539612    9736     1511558
# 23                                   Mizoram        49950    9084       40681
# 3                                      Assam       581398    8772      567113
# 25                                    Odisha       996153    8661      980471
# 31                                 Telengana       653202    6939      642416
# 21                                   Manipur       108948    5721      101505
# ...

# %% [markdown]
# # 3. Minimum Death Ratio

# %%
death = covid.sort_values('Death Ratio (%)', ascending= True)

# %%
death
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        10657       4       10649
# 23                                   Mizoram        49950    9084       40681
# 2                          Arunachal Pradesh        51655    1763       49640
# 18                               Lakshadweep        10295      34       10210
# 16                                    Kerala      3724030  175695     3529465
# 31                                 Telengana       653202    6939      642416
# 1                             Andhra Pradesh      1995669   16341     1965657
# 25                                    Odisha       996153    8661      980471
# 28                                 Rajasthan       953960     163      944843
# 3                                      Assam       581398    8772      567113
# 32                                   Tripura        81584    1436       79366
# ...

# %% [markdown]
# # 4. Highest Discharged Patients

# %%
discharge = covid.sort_values('Discharged', ascending =  False)

# %%
discharge
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      6401213   64790     6201168
# 16                                    Kerala      3724030  175695     3529465
# 15                                 Karnataka      2931827   21507     2873281
# 30                                Tamil Nadu      2592436   20225     2537632
# 1                             Andhra Pradesh      1995669   16341     1965657
# 33                             Uttar Pradesh      1708991     420     1685785
# 35                               West Bengal      1539612    9736     1511558
# 8                                      Delhi      1437156     471     1411612
# 6                               Chhattisgarh      1003870    1037      989284
# 25                                    Odisha       996153    8661      980471
# 28                                 Rajasthan       953960     163      944843
# ...

# %% [markdown]
# # 5. Highest Total Case

# %%
total_case = covid.sort_values('Total Cases', ascending = False)

# %%
total_case
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      6401213   64790     6201168
# 16                                    Kerala      3724030  175695     3529465
# 15                                 Karnataka      2931827   21507     2873281
# 30                                Tamil Nadu      2592436   20225     2537632
# 1                             Andhra Pradesh      1995669   16341     1965657
# 33                             Uttar Pradesh      1708991     420     1685785
# 35                               West Bengal      1539612    9736     1511558
# 8                                      Delhi      1437156     471     1411612
# 6                               Chhattisgarh      1003870    1037      989284
# 25                                    Odisha       996153    8661      980471
# 28                                 Rajasthan       953960     163      944843
# ...

# %% [markdown]
# # 6. Highest Active Ratio

# %%
har = covid.sort_values('Active Ratio (%)', ascending = False)

# %%
har
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 23                                   Mizoram        49950    9084       40681
# 29                                    Sikkim        28830    1982       26485
# 21                                   Manipur       108948    5721      101505
# 22                                 Meghalaya        72412    3591       67581
# 16                                    Kerala      3724030  175695     3529465
# 24                                  Nagaland        29274    1088       27579
# 2                          Arunachal Pradesh        51655    1763       49640
# 32                                   Tripura        81584    1436       79366
# 3                                      Assam       581398    8772      567113
# 12                          Himachal Pradesh       210719    2705      204457
# 31                                 Telengana       653202    6939      642416
# ...

# %% [markdown]
# # 7. Discharge Ratio

# %%
dr = covid.sort_values('Discharge Ratio (%)', ascending = True)

# %%
dr
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 23                                   Mizoram        49950    9084       40681
# 29                                    Sikkim        28830    1982       26485
# 21                                   Manipur       108948    5721      101505
# 22                                 Meghalaya        72412    3591       67581
# 24                                  Nagaland        29274    1088       27579
# 16                                    Kerala      3724030  175695     3529465
# 2                          Arunachal Pradesh        51655    1763       49640
# 20                               Maharashtra      6401213   64790     6201168
# 12                          Himachal Pradesh       210719    2705      204457
# 27                                    Punjab       600008     543      583120
# 32                                   Tripura        81584    1436       79366
# ...

# %% [markdown]
# # Deaths

# %%
death_1 = covid.sort_values('Deaths', ascending = False)

# %%
death_1
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      6401213   64790     6201168
# 15                                 Karnataka      2931827   21507     2873281
# 30                                Tamil Nadu      2592436   20225     2537632
# 8                                      Delhi      1437156     471     1411612
# 33                             Uttar Pradesh      1708991     420     1685785
# 16                                    Kerala      3724030  175695     3529465
# 35                               West Bengal      1539612    9736     1511558
# 27                                    Punjab       600008     543      583120
# 1                             Andhra Pradesh      1995669   16341     1965657
# 6                               Chhattisgarh      1003870    1037      989284
# 19                            Madhya Pradesh       792054      95      781444
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.pairplot(covid)

# %% [markdown]
# # Active

# %%
plt.figure(figsize=(20,14))
sns.pointplot(data=active, x='State/UTs', y='Active', color='red');
plt.tick_params(axis='x', which='major', labelsize=15, rotation=90)
plt.tick_params(axis='y', which='major', labelsize=15)

# %% [markdown]
# # Total Case

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(x='State/UTs', y='Total Cases', data=total_case, color='red');

# %% [markdown]
# # Death Ratio

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(x='State/UTs', y='Death Ratio (%)', data=death, color='red');

# %% [markdown]
# # Discharged Ratio

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(x='State/UTs', y='Discharge Ratio (%)', data=dr, color='red');

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(x='State/UTs',y='Active Ratio (%)',data=har,color='red');

# %% [markdown]
# # Data Corellation

# %%
covid.corr()
# Out:
#                      Total Cases    Active  Discharged    Deaths  \
# Total Cases             1.000000  0.663181    0.999898  0.907023
# Active                  0.663181  1.000000    0.653333  0.393393
# Discharged              0.999898  0.653333    1.000000  0.908726
# Deaths                  0.907023  0.393393    0.908726  1.000000
# Active Ratio (%)       -0.115642  0.167718   -0.121017 -0.134799
# Discharge Ratio (%)     0.102671 -0.143148    0.107895  0.087475
# Death Ratio (%)         0.092273 -0.167600    0.094009  0.291043
#
#                      Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# Total Cases                 -0.115642             0.102671         0.092273
# Active                       0.167718            -0.143148        -0.167600
# Discharged                  -0.121017             0.107895         0.094009
# Deaths                      -0.134799             0.087475         0.291043
# ...

# %% [markdown]
# # Death

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(x='State/UTs',y='Deaths',data=death_1, color='red');
